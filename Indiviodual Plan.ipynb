# %% [markdown]
# # Indiviodual Plan

# %% [markdown]
# github link: https://github.com/zyl200708-sketch/dsci-100-project-eric.git

# %% [markdown]
# ## importing data(player(1))

# %%
library(tidyverse)
url_players = 'https://drive.google.com/uc?export=download&id=1hhtMiO5tqLPAIPATESCbF4wFB3HGy7DQ'
players <- read_csv(url_players)
head(players)
dim(players)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   experience subscribe
# 1 Pro         TRUE
# 2 Veteran     TRUE
# ...

# %%
distinct(players, experience)
distinct(players, subscribe)
distinct(players, gender)
distinct(players, Age)
players |> summarize(mean_played_hours = mean(played_hours, na.rm = TRUE),
                        mean_age = mean(Age, na.rm = TRUE))
# Out:
#   experience
# 1 Pro
# 2 Veteran
# 3 Amateur
# 4 Regular
# 5 Beginner
#   subscribe
# 1  TRUE
# 2 FALSE
#   gender
# 1 Male
# 2 Female
# 3 Non-binary
# 4 Prefer not to say
# 5 Agender
# 6 Two-Spirited
# 7 Other
#    Age
# 1   9
# 2  17
# 3  21
# 4  19
# 5  47
# 6  22
# 7  23
# 8  25
# 9  58
# 10 28
# 11 18
# 12 33
# 13 26
# 14 20
# 15 24
# 16 27
# 17 42
# 18 11
# 19 10
# 20 38
# 21 14
# 22 15
# 23 37
# 24 16
# 25 12
# 26 46
# 27 32
# 28 49
# 29 45
# 30 NA
# 31 50
# 32 44
# 33 57
#   mean_played_hours mean_age
# 1 5.845918          21.13918

# %%
url_sessions = "https://drive.google.com/uc?export=download&id=1qoiGA-idlIr7LE2972cbrWjOH2ar-88b"
sessions <- read_csv(url_sessions)
head(sessions)
dim(sessions)
# Out:
# Rows: 1535 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): hashedEmail, start_time, end_time
# dbl (2): original_start_time, original_end_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   hashedEmail
# 1 bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 2 36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 3 f8f5477f5a2e53616ae37421b1c660b971192bd8ff77e3398304c7ae42581fdc
# 4 bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 5 36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 6 bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
#   start_time       end_time         original_start_time original_end_time
# 1 30/06/2024 18:12 30/06/2024 18:24 1.71977e+12         1.71977e+12
# ...

# %% [markdown]
# ## **Data Descripton**

# %% [markdown]
# ### **players**

# %% [markdown]
# #### It has 196 obervations and 7 variables

# %% [markdown]
# `experience`: character, experience level of players, such as: `Pro`,`Veteran`,`Amateur`,`Regular`
